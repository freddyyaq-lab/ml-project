# %% [markdown]
# # EDA
#
# Este notebook tiene como objetivo realizar un análisis exploratorio del conjunto de datos
# relacionado con churn de clientes, con el fin de comprender su estructura, calidad,
# distribución de las variables y posibles relaciones entre ellas.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from Cargar_datos import cargar_datos

# %%
df = cargar_datos("../Base_de_datos.xlsx")

# %%
df.head()
# Out:
#    tipo_credito      fecha_prestamo  capital_prestado  plazo_meses  \
# 0             7 2024-12-21 11:31:35         3692160.0           10
# 1             4 2025-04-22 09:47:35          840000.0            6
# 2             9 2026-01-08 12:22:40         5974028.4           10
# 3             4 2025-08-04 12:04:10         1671240.0            6
# 4             9 2025-04-26 11:24:26         2781636.0           11
#
#    edad_cliente   tipo_laboral  salario_cliente  total_otros_prestamos  \
# 0            42  Independiente          8000000                2500000
# 1            60       Empleado          3000000                2000000
# 2            36  Independiente          4036000                 829000
# 3            48       Empleado          1524547                 498000
# 4            44       Empleado          5000000                4000000
#
#    cuota_pactada    puntaje  ...  saldo_mora  saldo_total  saldo_principal  \
# 0         341296  88.768094  ...         0.0      51258.0          51258.0
# 1         124876  95.227787  ...         0.0       8673.0           8673.0
# 2         529554  47.613894  ...         0.0      18702.0          18702.0
# 3         252420  95.227787  ...         0.0      15782.0          15782.0
# 4         217037  95.227787  ...         0.0     204804.0         204804.0
#
#    saldo_mora_codeudor  creditos_sectorFinanciero  creditos_sectorCooperativo  \
# 0                  0.0                          5                           0
# 1                  0.0                          0                           0
# 2                  0.0                          3                           0
# 3                  0.0                          3                           0
# 4                  0.0                          3                           0
#
#    creditos_sectorReal  promedio_ingresos_datacredito  tendencia_ingresos  \
# 0                    0                       908526.0             Estable
# 1                    2                       939017.0           Creciente
# 2                    0                            NaN                 NaN
# 3                    0                      1536193.0           Creciente
# 4                    1                       933473.0           Creciente
#
#    Pago_atiempo
# 0             1
# 1             1
# 2             0
# 3             1
# 4             1
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (10763, 23)

# %%
df.describe(include='all').T
# Out:
#                                  count unique        top  freq  \
# tipo_credito                   10763.0    NaN        NaN   NaN
# fecha_prestamo                   10763    NaN        NaN   NaN
# capital_prestado               10763.0    NaN        NaN   NaN
# plazo_meses                    10763.0    NaN        NaN   NaN
# edad_cliente                   10763.0    NaN        NaN   NaN
# tipo_laboral                     10763      2   Empleado  6754
# salario_cliente                10763.0    NaN        NaN   NaN
# total_otros_prestamos          10763.0    NaN        NaN   NaN
# cuota_pactada                  10763.0    NaN        NaN   NaN
# puntaje                        10763.0    NaN        NaN   NaN
# puntaje_datacredito            10757.0    NaN        NaN   NaN
# cant_creditosvigentes          10763.0    NaN        NaN   NaN
# huella_consulta                10763.0    NaN        NaN   NaN
# saldo_mora                     10607.0    NaN        NaN   NaN
# saldo_total                    10607.0    NaN        NaN   NaN
# saldo_principal                10358.0    NaN        NaN   NaN
# saldo_mora_codeudor            10173.0    NaN        NaN   NaN
# creditos_sectorFinanciero      10763.0    NaN        NaN   NaN
# creditos_sectorCooperativo     10763.0    NaN        NaN   NaN
# creditos_sectorReal            10763.0    NaN        NaN   NaN
# promedio_ingresos_datacredito   7833.0    NaN        NaN   NaN
# tendencia_ingresos                7831     46  Creciente  5294
# Pago_atiempo                   10763.0    NaN        NaN   NaN
#
#                                                         mean  \
# tipo_credito                                        5.411131
# fecha_prestamo                 2025-04-16 23:06:02.111121664
# capital_prestado                              2434315.001319
# plazo_meses                                        10.575583
# edad_cliente                                        43.94862
# tipo_laboral                                             NaN
# salario_cliente                              17216431.459909
# total_otros_prestamos                         6238869.648518
# cuota_pactada                                  243617.406671
# puntaje                                            91.170036
# puntaje_datacredito                               780.790834
# cant_creditosvigentes                               5.726749
# huella_consulta                                     4.228561
# saldo_mora                                          7.746017
# saldo_total                                     45937.408127
# saldo_principal                                 40346.168179
# saldo_mora_codeudor                                 0.260002
# creditos_sectorFinanciero                           2.779987
# creditos_sectorCooperativo                          0.269813
# creditos_sectorReal                                 1.302704
# promedio_ingresos_datacredito                 2005156.811822
# tendencia_ingresos                                       NaN
# Pago_atiempo                                        0.952523
#
#                                                min  \
# tipo_credito                                   4.0
# fecha_prestamo                 2024-11-26 09:17:04
# capital_prestado                          360000.0
# plazo_meses                                    2.0
# edad_cliente                                  19.0
# tipo_laboral                                   NaN
# salario_cliente                                0.0
# total_otros_prestamos                          0.0
# cuota_pactada                              23944.0
# puntaje                                  -38.00999
# puntaje_datacredito                           -7.0
# cant_creditosvigentes                          0.0
# huella_consulta                                0.0
# saldo_mora                                     0.0
# saldo_total                                    0.0
# saldo_principal                                0.0
# saldo_mora_codeudor                            0.0
# creditos_sectorFinanciero                      0.0
# creditos_sectorCooperativo                     0.0
# creditos_sectorReal                            0.0
# promedio_ingresos_datacredito                  0.0
# tendencia_ingresos                             NaN
# Pago_atiempo                                   0.0
#
#                                                       25%  \
# tipo_credito                                          4.0
# fecha_prestamo                 2025-01-20 17:33:07.500000
# capital_prestado                                1224831.0
# plazo_meses                                           6.0
# edad_cliente                                         33.0
# tipo_laboral                                          NaN
# salario_cliente                                 2000000.0
# total_otros_prestamos                            500000.0
# cuota_pactada                                    121041.5
# puntaje                                         95.227787
# puntaje_datacredito                                 757.0
# cant_creditosvigentes                                 3.0
# huella_consulta                                       2.0
# saldo_mora                                            0.0
# saldo_total                                        2898.0
# saldo_principal                                    2690.0
# saldo_mora_codeudor                                   0.0
# creditos_sectorFinanciero                             1.0
# creditos_sectorCooperativo                            0.0
# creditos_sectorReal                                   0.0
# promedio_ingresos_datacredito                    925157.0
# tendencia_ingresos                                    NaN
# Pago_atiempo                                          1.0
#
#                                                50%                  75%  \
# tipo_credito                                   4.0                  9.0
# fecha_prestamo                 2025-03-27 16:23:12  2025-06-16 13:27:58
# capital_prestado                         1921920.0            3084840.0
# plazo_meses                                   10.0                 12.0
# edad_cliente                                  42.0                 53.0
# tipo_laboral                                   NaN                  NaN
# salario_cliente                          3000000.0            4875808.0
# total_otros_prestamos                    1000000.0            2000000.0
# cuota_pactada                             182863.0             287833.5
# puntaje                                  95.227787            95.227787
# puntaje_datacredito                          791.0                825.0
# cant_creditosvigentes                          5.0                  8.0
# huella_consulta                                4.0                  6.0
# saldo_mora                                     0.0                  0.0
# saldo_total                                16178.0              52982.0
# saldo_principal                            14442.5             47632.25
# saldo_mora_codeudor                            0.0                  0.0
# creditos_sectorFinanciero                      2.0                  4.0
# creditos_sectorCooperativo                     0.0                  0.0
# creditos_sectorReal                            1.0                  2.0
# promedio_ingresos_datacredito            1204496.0            2231859.0
# tendencia_ingresos                             NaN                  NaN
# Pago_atiempo                                   1.0                  1.0
#
#                                                max               std
# tipo_credito                                  68.0          2.338279
# fecha_prestamo                 2026-04-26 18:43:52               NaN
# capital_prestado                        41444152.8    1909642.758997
# plazo_meses                                   90.0          6.632082
# edad_cliente                                 123.0         15.060877
# tipo_laboral                                   NaN               NaN
# salario_cliente                      22000000000.0  355476717.603482
# total_otros_prestamos                 6787675263.0  118418316.941069
# cuota_pactada                            3816752.0     210493.694608
# puntaje                                  95.227787         16.465441
# puntaje_datacredito                          999.0        104.878031
# cant_creditosvigentes                         62.0          3.977162
# huella_consulta                               29.0          3.064683
# saldo_mora                                 12534.0        225.955117
# saldo_total                              5116066.0     106269.789916
# saldo_principal                          1562285.0      71242.440332
# saldo_mora_codeudor                         2145.0         21.772917
# creditos_sectorFinanciero                     51.0          2.748807
# creditos_sectorCooperativo                    13.0          0.716471
# creditos_sectorReal                           25.0           1.82443
# promedio_ingresos_datacredito           38106581.0    2144116.150336
# tendencia_ingresos                             NaN               NaN
# Pago_atiempo                                   1.0          0.212668

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10763 entries, 0 to 10762
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   tipo_credito                   10763 non-null  int64
#  1   fecha_prestamo                 10763 non-null  datetime64[ns]
#  2   capital_prestado               10763 non-null  float64
#  3   plazo_meses                    10763 non-null  int64
#  4   edad_cliente                   10763 non-null  int64
#  5   tipo_laboral                   10763 non-null  object
#  6   salario_cliente                10763 non-null  int64
#  7   total_otros_prestamos          10763 non-null  int64
#  8   cuota_pactada                  10763 non-null  int64
#  9   puntaje                        10763 non-null  float64
#  10  puntaje_datacredito            10757 non-null  float64
#  11  cant_creditosvigentes          10763 non-null  int64
#  12  huella_consulta                10763 non-null  int64
#  13  saldo_mora                     10607 non-null  float64
#  14  saldo_total                    10607 non-null  float64
#  15  saldo_principal                10358 non-null  float64
#  16  saldo_mora_codeudor            10173 non-null  float64
#  17  creditos_sectorFinanciero      10763 non-null  int64
#  18  creditos_sectorCooperativo     10763 non-null  int64
#  19  creditos_sectorReal            10763 non-null  int64
#  20  promedio_ingresos_datacredito  7833 non-null   float64
#  21  tendencia_ingresos             7831 non-null   object
#  22  Pago_atiempo                   10763 non-null  int64
# dtypes: datetime64[ns](1), float64(8), int64(12), object(2)
# memory usage: 1.9+ MB

# %%
df.describe().round(4)
# Out:
#        tipo_credito                 fecha_prestamo  capital_prestado  \
# count    10763.0000                          10763      1.076300e+04
# mean         5.4111  2025-04-16 23:06:02.111121664      2.434315e+06
# min          4.0000            2024-11-26 09:17:04      3.600000e+05
# 25%          4.0000     2025-01-20 17:33:07.500000      1.224831e+06
# 50%          4.0000            2025-03-27 16:23:12      1.921920e+06
# 75%          9.0000            2025-06-16 13:27:58      3.084840e+06
# max         68.0000            2026-04-26 18:43:52      4.144415e+07
# std          2.3383                            NaN      1.909643e+06
#
#        plazo_meses  edad_cliente  salario_cliente  total_otros_prestamos  \
# count   10763.0000    10763.0000     1.076300e+04           1.076300e+04
# mean       10.5756       43.9486     1.721643e+07           6.238870e+06
# min         2.0000       19.0000     0.000000e+00           0.000000e+00
# 25%         6.0000       33.0000     2.000000e+06           5.000000e+05
# 50%        10.0000       42.0000     3.000000e+06           1.000000e+06
# 75%        12.0000       53.0000     4.875808e+06           2.000000e+06
# max        90.0000      123.0000     2.200000e+10           6.787675e+09
# std         6.6321       15.0609     3.554767e+08           1.184183e+08
#
#        cuota_pactada     puntaje  puntaje_datacredito  ...  huella_consulta  \
# count   1.076300e+04  10763.0000           10757.0000  ...       10763.0000
# mean    2.436174e+05     91.1700             780.7908  ...           4.2286
# min     2.394400e+04    -38.0100              -7.0000  ...           0.0000
# 25%     1.210415e+05     95.2278             757.0000  ...           2.0000
# 50%     1.828630e+05     95.2278             791.0000  ...           4.0000
# 75%     2.878335e+05     95.2278             825.0000  ...           6.0000
# max     3.816752e+06     95.2278             999.0000  ...          29.0000
# std     2.104937e+05     16.4654             104.8780  ...           3.0647
#
#        saldo_mora   saldo_total  saldo_principal  saldo_mora_codeudor  \
# count  10607.0000  1.060700e+04     1.035800e+04           10173.0000
# mean       7.7460  4.593741e+04     4.034617e+04               0.2600
# min        0.0000  0.000000e+00     0.000000e+00               0.0000
# 25%        0.0000  2.898000e+03     2.690000e+03               0.0000
# 50%        0.0000  1.617800e+04     1.444250e+04               0.0000
# 75%        0.0000  5.298200e+04     4.763225e+04               0.0000
# max    12534.0000  5.116066e+06     1.562285e+06            2145.0000
# std      225.9551  1.062698e+05     7.124244e+04              21.7729
#
#        creditos_sectorFinanciero  creditos_sectorCooperativo  \
# count                 10763.0000                  10763.0000
# mean                      2.7800                      0.2698
# min                       0.0000                      0.0000
# 25%                       1.0000                      0.0000
# 50%                       2.0000                      0.0000
# 75%                       4.0000                      0.0000
# max                      51.0000                     13.0000
# std                       2.7488                      0.7165
#
#        creditos_sectorReal  promedio_ingresos_datacredito  Pago_atiempo
# count           10763.0000                   7.833000e+03    10763.0000
# mean                1.3027                   2.005157e+06        0.9525
# min                 0.0000                   0.000000e+00        0.0000
# 25%                 0.0000                   9.251570e+05        1.0000
# 50%                 1.0000                   1.204496e+06        1.0000
# 75%                 2.0000                   2.231859e+06        1.0000
# max                25.0000                   3.810658e+07        1.0000
# std                 1.8244                   2.144116e+06        0.2127
#
# [8 rows x 21 columns]

# %% [markdown]
# ### Valores faltantes
#
# Se identificó la presencia de valores faltantes en el conjunto de datos. En particular,
# algunas variables presentan un porcentaje significativo de datos ausentes, lo cual será
# tenido en cuenta en etapas posteriores del proyecto para definir estrategias de tratamiento.

# %%
round(df.isnull().mean() * 100,4).sort_values(ascending=False)
# Out:
# tendencia_ingresos               27.2415
# promedio_ingresos_datacredito    27.2229
# saldo_mora_codeudor               5.4817
# saldo_principal                   3.7629
# saldo_total                       1.4494
# saldo_mora                        1.4494
# puntaje_datacredito               0.0557
# tipo_credito                      0.0000
# huella_consulta                   0.0000
# creditos_sectorReal               0.0000
# creditos_sectorCooperativo        0.0000
# creditos_sectorFinanciero         0.0000
# cant_creditosvigentes             0.0000
# fecha_prestamo                    0.0000
# puntaje                           0.0000
# cuota_pactada                     0.0000
# total_otros_prestamos             0.0000
# salario_cliente                   0.0000
# tipo_laboral                      0.0000
# edad_cliente                      0.0000
# plazo_meses                       0.0000
# capital_prestado                  0.0000
# Pago_atiempo                      0.0000
# dtype: float64

# %% [markdown]
# ### Variable objetivo
#
# La variable objetivo del proyecto es `Pago_atiempo`, la cual corresponde a una variable
#
# binaria donde:
# - 1 indica que el cliente realizó el pago de manera oportuna.
# - 0 indica que el cliente incurrió en mora o incumplimiento.
#
# De igual forma, de evidencia que la variable objetivo presenta una distribución desbalanceada, lo cual es relevante para
# etapas posteriores de modelado, ya que puede influir en la selección de métricas y técnicas
# de evaluación.

# %%
df["Pago_atiempo"].value_counts(normalize=True) * 100
# Out:
# Pago_atiempo
# 1    95.252253
# 0     4.747747
# Name: proportion, dtype: float64

# %% [markdown]
# ### Distribución de clientes según pago a tiempo

# %%
df["Pago_atiempo"].value_counts().plot(kind="bar")
plt.title("Distribución de la variable Pago_atiempo")
plt.xlabel("Pago a tiempo")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ### Distribución de los salarios de los clientes

# %%
plt.figure()
df["salario_cliente"].hist(bins=30)
plt.title("Distribución del salario del cliente")
plt.xlabel("Salario")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ### Distribución de la edad de los clientes

# %%
plt.figure()
df["edad_cliente"].hist(bins=30)
plt.title("Distribución de la edad del cliente")
plt.xlabel("Edad")
plt.ylabel("Frecuencia")
plt.show()

# %%
plt.figure()
sns.boxplot(x="Pago_atiempo", y="salario_cliente", data=df)
plt.title("Salario del cliente vs Pago a tiempo")
plt.show()

# %%
plt.figure()
sns.boxplot(x="Pago_atiempo", y="puntaje_datacredito", data=df)
plt.title("Puntaje Datacrédito vs Pago a tiempo")
plt.show()

# %% [markdown]
# ### Relación entre el tipo laboral (Categorica) y el pago a tiempo

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="tipo_laboral", hue="Pago_atiempo", data=df)
plt.title("Tipo laboral según pago a tiempo")
plt.show()

# %% [markdown]
# ### Matriz de correlación entre variables numéricas

# %%
plt.figure(figsize=(15,8))
sns.heatmap(
    df.select_dtypes(include=["int64", "float64"]).corr(),
    cmap="coolwarm",
    annot=True
)
plt.title("Matriz de correlación entre variables numéricas")
plt.show()

# %% [markdown]
# El analisis exploratorio permitio comprender la estructura del conjunto de datos, identificar el tipo de variables, la distribucion de la variable target y la presencia de valores atipicos y datos faltantes.
#
# Se evidencio un fuerte desbalance en la variable target, asi como diferencias en la distribucion de algunas variables numericas y categoricas frente al estado de pago.
